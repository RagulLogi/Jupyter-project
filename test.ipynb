# %%
print("HI")
# Out:
# HI

# %%
print("Hello Ragul 🚀")
# Out:
# Hello Ragul 🚀

# %%
print("Branch ragul update 🚀")
# Out:
# Branch ragul update 🚀

# %%
print("NEW CHANGE FROM RAGUL BRANCH 🚀")
# Out:
# NEW CHANGE FROM RAGUL BRANCH 🚀
